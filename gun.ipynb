# %% [markdown]
# visualization ideas https://www.data.gov/
#    a. number of shootings/100 people in order, color coded by the gun law scorecard rating https://lawcenter.giffords.org/scorecard/
#    b. state senators ranked by highest donations from gun rights groups/conservative donors/ vs. gun laws in their state vs. public opinion in those states
#    c. trauma center accessibility versus gun death (multifaceted issue) https://www.chicagotribune.com/news/opinion/commentary/ct-perspec-trauma-emergency-medicine-university-chicago-gunfire-0628-story.html
#    https://journals.lww.com/jtrauma/Citation/2017/01000/Gun_violence_is_structural_violence___Our_role_as.32.aspx

# %%
import pandas as pd
pop = {
        "Alabama":4858979,
        "Alaska": 738432,
        "Arizona": 682865,
        "Arkansas": 2978204,
        "California": 39144818,
        "Colorado": 5456574,
        "Connecticut": 3590886,
        "Delaware": 945934,
        "District of Columbia": 702455,
        "Florida": 20271272,
        "Georgia": 10214860, 
        "Hawaii": 1431603,
        "Idaho": 1654930,
        "Illinois": 12859995,
        "Indiana": 6619680,
        "Iowa": 3123899,
        "Kansas": 2911641,
        "Kentucky": 4425092,
        "Louisiana": 4670724,
        "Maine": 1329328,
        "Maryland": 6006401,
        "Massachusetts": 6794422,
        "Michigan": 9922576,
        "Minnesota": 5489594,
        "Mississippi":2992333,
        "Missouri": 6083672,
        "Montana":1032949,
        "Nebraska": 1896190,
        "Nevada": 2890845,
        "New Hampshire": 1330608,
        "New Jersey": 8958013,
        "New Mexico": 2085109,
        "New York": 19795791,
        "North Carolina": 10042802,
        "North Dakota": 756927,
        "Ohio": 11613423,
        "Oklahoma": 3911338,
        "Oregon": 4028977,
        "Pennsylvania": 12802503,
        "Rhode Island": 1056298,
        "South Carolina": 4896146,
        "South Dakota": 858469,
        "Tennessee": 6600299,
        "Texas": 27469114,
        "Utah": 2995919,
        "Vermont": 626042,
        "Virginia": 8382993,
        "Washington": 7170351,
        "West Virginia": 1844128,
        "Wisconsin": 5771337,
        "Wyoming": 586107,
    }

# %%
gun = pd.read_csv("gun.csv", header=0)
#display(gun)

# %%
states = pop.keys()
pop_values = list(pop.values())
v = pd.DataFrame(data = pop_values , columns=['pop_values'])
#display(v)
#gun = gun.sort_values("n_killed", ascending = False)

# %%
state = gun.state
gun.sort_values("state")

#shootings = gun.groupby(by = "state")
#shootings.size()

n = gun[["state", "n_killed"]]
#n.sort_values('state')
#shootings = n.groupby(by="state").size().to_frame(name = "size")
#shootings['pop'] = pop_values
#shootings['normalized'] = shootings['size']*(1/shootings['pop'])*100000
#shootings.sort_values("normalized", ascending = False)
# Out:
#                        size       pop  normalized
# state
# District of Columbia   3195    702455  454.833406
# Arizona                2328    682865  340.916579
# Alaska                 1349    738432  182.684391
# Delaware               1685    945934  178.130821
# Louisiana              8103   4670724  173.484882
# South Carolina         6939   4896146  141.723715
# Illinois              17556  12859995  136.516383
# Mississippi            3599   2992333  120.274047
# Tennessee              7626   6600299  115.540220
# Alabama                5471   4858979  112.595671
# Missouri               6631   6083672  108.996672
# Maryland               5798   6006401   96.530352
# Arkansas               2842   2978204   95.426640
# Kentucky               4157   4425092   93.941550
# Indiana                5852   6619680   88.403065
# Oklahoma               3455   3911338   88.332944
# Ohio                  10244  11613423   88.208274
# Massachusetts          5981   6794422   88.028091
# ...
